# %%
from pydantic_ai import Agent
import requests

# %%
storyGen_prompt = '''
You are a creative storytelling assistant for children.

Create a 7-day short continuous adventure story.

Include:
1. An INTRODUCTION (before Day 1)
2. Then a 7-day story
3. An OUTRO to conclude the ending of the story

Theme: {theme}
Overall Goal: {goal}

The introduction should:
- Set the scene
- Introduce the main character
- Explain the mission
- Naturally lead into Day 1

The outro should:
- Take place AFTER Day 7 is completed
- Clearly show that the CHILD helped the main character succeed
- Resolve the overall goal in a satisfying way
- Celebrate the child's effort and impact
- End with a warm, magical closing feeling
- Be short (2–3 sentences max)

The story must:
- Be continuous across 7 days (like chapters)
- Each day must include the given task as the main highlight
- Each task must be naturally integrated as a meaningful action that helps the hero progress toward the overall goal
- Be fun, motivating, and suitable for a child
- Build toward the final resolution in the outro (NOT during the days)

Interpret tasks creatively in a story context.

Specific Style Instructions:
1. Keep EVERY "story" section concise (2–3 sentences max), including intro and outro.
2. IMPORTANT: The character should NOT complete the task. Instead, they face a blocker or challenge.
3. Each day MUST end with a direct call to the child (e.g., a question or request for help).
4. The story assumes that once the child completes the task, the hero can move forward.
5. Use simple, clear, child-friendly language.

Tasks:

Day 1: {task1}
Day 2: {task2}
Day 3: {task3}
Day 4: {task4}
Day 5: {task5}
Day 6: {task6}
Day 7: {task7}

Return ONLY valid JSON in the following format:

{{
  "intro": {{
    "title": "...",
    "story": "..."
  }},
  "days": [
    {{
      "day": 1,
      "title": "...",
      "story": "..."
    }},
    {{
      "day": 2,
      "title": "...",
      "story": "..."
    }},
    ...
  ],
  "outro": {{
    "title": "...",
    "story": "..."
  }}
}}
'''

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
 system_prompt = storyGen_prompt.format(theme='a fairy looking for a magical flower',
                                        goal= 'problem solving',
                                        task1= 'do your math homework',
                                        task2= 'draw an art project',
                                        task3= 'say the days of the week',
                                        task4= 'clean your room',
                                        task5= 'find where the cat is',
                                        task6= 'grow and take care of a plant',
                                        task7= 'try saying this word'
                                       )

# %%
story_agent = Agent(
    name="story_genarator",
    instructions= system_prompt,
    model= 'groq:llama-3.3-70b-versatile'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 story_agent = Agent(
#       2     name="story_genarator",
#       3     instructions= system_prompt,
#       4     model= 'groq:llama-3.3-70b-versatile'
#
# NameError: name 'Agent' is not defined

# %%
result = await story_agent.run()

# %%
print(result.output)
# Out:
# ```
# {
#   "intro": {
#     "title": "The Magical Quest Begins",
#     "story": "In a land of sparkling sunshine, a little fairy named Luna set out on a mission to find the rare and magical Golden Bloom flower, which only blooms once a year. To find it, she needs help from a friend, and that's where you come in. Luna's journey starts tomorrow, but first, she needs to get her map ready, and for that, she needs someone to help her with a very important task."
#   },
#   "days": [
#     {
#       "day": 1,
#       "title": "Mapping the Way",
#       "story": "Luna's map has some missing numbers that need to be filled in, but she can't do her math homework because the numbers are all jumbled up. Can you help Luna by doing your math homework so she can fix her map and start her journey?"
#     },
#     {
#       "day": 2,
#       "title": "Drawing the Path",
#       "story": "Luna's map is still incomplete because she needs a picture of the Golden Bloom flower to know what she's looking for, but her art supplies are all messy. Can you help Luna by drawing an art project of the flower, so she knows what to search for?"
#     },
#     {
#       "day": 3,
#       "title": "Timing is Everything",
#       "story": "Luna knows the Golden Bloom flower only blooms on a specific day, but she can't remember the order of the days of the week. Can you help Luna by saying the days of the week in the correct order, so she can plan her trip?"
#     },
#     {
#       "day": 4,
#       "title": "A Clear Path",
#       "story": "Luna's room is so cluttered that she can't find her backpack, and without it, she can't carry all the things she needs for her journey. Can you help Luna by cleaning your room, so she can get inspired to clean hers too?"
#     },
#     {
#       "day": 5,
#       "title": "Finding a Friend",
#       "story": "Luna's cat, Whiskers, has gone missing, and Luna can't leave without saying goodbye. Can you help Luna by finding where the cat is hiding, so she can give Whiskers a hug before she leaves?"
#     },
#     {
#       "day": 6,
#       "title": "Nourishing the Journey",
#       "story": "Luna wants to bring a special plant that blooms in the same time as the Golden Bloom, but she needs someone to show her how to take care of it. Can you help Luna by growing and taking care of a plant, so she can learn from you?"
#     },
#     {
#       "day": 7,
#       "title": "The Final Word",
#       "story": "Luna has finally reached the garden where the Golden Bloom flower is supposed to bloom, but the sign at the entrance has a word she's never seen before: 'floralia'. Can you help Luna by trying to say this word, so she can unlock the gate and find the flower?"
#     }
#   ],
#   "outro": {
#     "title": "The Magical Conclusion",
#     "story": "With your help, Luna found the Golden Bloom flower, and its magic filled the land with sparkling sunshine. You made Luna's journey possible, and she's forever grateful for your help and friendship. Congratulations, you're a true magical helper!"
#   }
# }
# ```
